# %%
import matplotlib.pyplot as plt
from datetime import datetime
import synoptic.services as ss
from synoptic.services import stations_timeseries

lat = 42.0
lon = -93.7

# ---------------------------------------------------------------------
# Request a single station by listing the station id.  
# ---------------------------------------------------------------------

# Station ID can be found at Mesowest or by searcing by radius (below).
station = 'KAMW'

params = dict(
    stid=station,
    vars=['air_temp', 'dew_point_temperature'],
    start=datetime(2020, 4, 1),
    end=datetime(2020, 10, 30)
)
data = stations_timeseries(verbose='HIDE', **params)

# Filter data to get only 00z obs.
sfc_obs = data.loc[(data.index.hour == 17) & (data.index.minute == 30)]

# convert datetime column to just date
sfc_obs['date'] = sfc_obs.index.date
sfc_obs.reset_index(inplace=True)
sfc_obs.set_index('date', inplace=True)

sfc_obs

#2020-10-29 23:55:00+00:00

# ---------------------------------------------------------------------
# Search for stations in a radius. 
# ---------------------------------------------------------------------

# radius = [lat, lon, 5] # lat, lon, radius in km.
# params = dict(
#     radius=radius,
#     vars=['air_temp', 'dew_point_temperature'],
#     start=datetime(2020, 8, 15),
#     end=datetime(2020, 8, 18)
# )
# data = stations_timeseries(verbose='HIDE', **params)
# data
# ---------------------------------------------------------------------

# %%
import pandas as pd

# Filter data to get only 00z obs.
houlry_2mt = data.loc[(data.index.hour == 17) & (data.index.minute == 30)]

# convert datetime column to just date
houlry_2mt['date'] = houlry_2mt.index.date
houlry_2mt.drop(columns='dew_point_temperature_set_1', inplace=True)
houlry_2mt.reset_index(inplace=True)
houlry_2mt.set_index('date', inplace=True)
houlry_2mt
# Out:
# /var/folders/zs/pstrmbpn6t75t6hdl9_v8_8w0000gn/T/ipykernel_32781/3927520248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   houlry_2mt['date'] = houlry_2mt.index.date
# /var/folders/zs/pstrmbpn6t75t6hdl9_v8_8w0000gn/T/ipykernel_32781/3927520248.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   houlry_2mt.drop(columns='dew_point_temperature_set_1', inplace=True)
#                            date_time  air_temp  dew_point_temperature
# date
# 2020-04-01 2020-04-01 23:50:00+00:00      15.0                   5.93
# ...
